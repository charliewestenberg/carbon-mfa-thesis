# %%
#import necessary libraries
import pandas as pd

# %% [markdown]
# ### CCF

# %%
#creating ccf dataframe and cleaning it for use in calculations
# make sure ccf.csv and ccf.xlsx for final version contain the same carriers and ccfs, later methodologody cleaning step!
df_ccf = pd.read_csv('/Users/charlottewestenberg/Thesis/00data/from_excel/CCF.csv')
ccf_clean = df_ccf[['Carrier', 'Carbon content factor']].copy()
ccf_clean['Carbon content factor'] = pd.to_numeric(
    ccf_clean['Carbon content factor'], 
    errors='coerce'
)
ccf_clean = ccf_clean.dropna(subset=['Carbon content factor'])
ccf_clean
# Out:
#                                       Carrier  Carbon content factor
# 1                                   Hard coal                  0.716
# 2                                  Brown coal                  0.328
# 3                                        Peat                  0.282
# 4                                 Natural gas                 15.300
# 5                                   Crude oil                  0.846
# 6                                 Refined oil                  0.856
# 7                              Petroleum coke                  0.863
# 8                            Coke (from coal)                  0.823
# 9                     Petrochemical feedstock                  0.869
# 11                            Primary biomass                  0.500
# 12  Wood pellets / Timber of Biomass forestry                  0.476
# 13                          Crops & livestock                  0.480
# 14                           Non-food biomass                  0.620
# 16                                  Limestone                  0.120
# 17                            Virgin plastics                  0.741
# 18                            Transport fuels                  0.856
# 20                                       CO2                   0.270
# 21                                       CH4                   0.750
# 22                                         CO                  0.428
# 24                              Plastic waste                  0.741
# 26                      Plastics in buildings                  0.741
# 27                       Wood in construction                  0.476
# 28                           Bitumen in roads                  0.884

# %% [markdown]
# ### Fossil inflows 11/3

# %%
#creating fossil inflows dataframe and cleaning it for use in calculations
# If refering to Excel, use: pd.read_excel('[name].xlsx', sheet_name='XXX')
df_fossil_inflows = pd.read_csv('/Users/charlottewestenberg/Thesis/00data/from_excel/Fossil inflows.csv')
df_fossil_inflows
# Out:
#                                                  Flow  \
# 0   Crude oil, NGL, refinery feedstocks, additives...
# 1   Crude oil, NGL, refinery feedstocks, additives...
# 2   Crude oil, NGL, refinery feedstocks, additives...
# 3   Crude oil, NGL, refinery feedstocks, additives...
# 4                                        Oil products
# ..                                                ...
# 59                                        Natural gas
# 60                                        Natural gas
# 61                                        Natural gas
# 62                                        Natural gas
# 63                                        Natural gas
#
#                         Added info  Amount in dataset  \
# 0            Indigenous production           19057.03
# 1                          Imports          497079.54
# 2                          Exports           14406.38
# 3                  Change in stock            4042.54
# 4                          Imports          288398.08
# ..                             ...                ...
# 59           Indigenous production         1361966.08
# 60                         Imports        13916863.71
# 61                         Exports         2491951.72
# 62                 Change in stock          -91658.46
# 63  International maritime bunkers           20214.96
#
#                             Unit in dataset  Amount_tonnes      Carrier  \
# 0                           thousand_tonnes   1.905703e+07    Crude oil
# 1                           thousand_tonnes   4.970795e+08    Crude oil
# 2                           thousand_tonnes   1.440638e+07    Crude oil
# 3                           thousand_tonnes   4.042544e+06    Crude oil
# 4                           thousand_tonnes   2.883981e+08  Refined oil
# ..                                      ...            ...          ...
# 59  Terajoule (gross calorific value - GCV)   1.225769e+06          Gas
# 60  Terajoule (gross calorific value - GCV)   1.252518e+07          Gas
# 61  Terajoule (gross calorific value - GCV)   2.242757e+06          Gas
# 62  Terajoule (gross calorific value - GCV)  -8.249261e+04          Gas
# 63  Terajoule (gross calorific value - GCV)   1.819346e+04          Gas
#
#        Type                                             Source
# 0    Inflow  https://ec.europa.eu/eurostat/databrowser/view...
# 1    Inflow  https://ec.europa.eu/eurostat/databrowser/view...
# 2   Outflow  https://ec.europa.eu/eurostat/databrowser/view...
# 3     Stock  https://ec.europa.eu/eurostat/databrowser/view...
# 4    Inflow  https://ec.europa.eu/eurostat/databrowser/view...
# ..      ...                                                ...
# 59   Inflow  https://ec.europa.eu/eurostat/databrowser/view...
# 60   Inflow  https://ec.europa.eu/eurostat/databrowser/view...
# 61  Outflow  https://ec.europa.eu/eurostat/databrowser/view...
# 62    Stock  https://ec.europa.eu/eurostat/databrowser/view...
# 63  Outflow  https://ec.europa.eu/eurostat/databrowser/view...
#
# [64 rows x 8 columns]

# %%
df_fossil_inflows_clean = df_fossil_inflows.drop(columns=['Amount in dataset', 'Unit in dataset', 'Source'])
df_fossil_inflows_clean.head(30)
# Out:
#                                                  Flow  \
# 0   Crude oil, NGL, refinery feedstocks, additives...
# 1   Crude oil, NGL, refinery feedstocks, additives...
# 2   Crude oil, NGL, refinery feedstocks, additives...
# 3   Crude oil, NGL, refinery feedstocks, additives...
# 4                                        Oil products
# 5                                        Oil products
# 6                                        Oil products
# 7                                        Oil products
# 8                                           Hard coal
# 9                                           Hard coal
# 10                                          Hard coal
# 11                                          Hard coal
# 12                                         Anthracite
# 13                                         Anthracite
# 14                                         Anthracite
# 15                                            Lignite
# 16                                            Lignite
# 17                                            Lignite
# 18                                            Lignite
# 19                                        Coking coal
# 20                                        Coking coal
# 21                                        Coking coal
# 22                                        Coking coal
# 23                              Other bituminous coal
# 24                              Other bituminous coal
# 25                              Other bituminous coal
# 26                              Other bituminous coal
# 27                                         Brown coal
# 28                                         Brown coal
# 29                                         Brown coal
#
#                         Added info  Amount_tonnes      Carrier     Type
# 0            Indigenous production     19057031.0    Crude oil   Inflow
# 1                          Imports    497079537.0    Crude oil   Inflow
# 2                          Exports     14406378.0    Crude oil  Outflow
# 3                  Change in stock      4042544.0    Crude oil    Stock
# 4                          Imports    288398077.0  Refined oil   Inflow
# 5                          Exports    299995871.0  Refined oil  Outflow
# 6                  Change in stock      2165148.0  Refined oil    Stock
# 7   International maritime bunkers     39641986.0  Refined oil  Outflow
# 8            Indigenous production     49721789.0    Hard coal   Inflow
# 9                          Imports     92422554.0    Hard coal   Inflow
# 10                         Exports     10291620.0    Hard coal  Outflow
# 11                 Change in stock     -3499952.0    Hard coal    Stock
# 12                         Imports      1420663.0    Hard coal   Inflow
# 13                         Exports       260275.0    Hard coal  Outflow
# 14                 Change in stock        87401.0    Hard coal    Stock
# 15           Indigenous production    224909414.0   Brown coal   Inflow
# 16                         Imports       805566.0   Brown coal   Inflow
# 17                         Exports      2716868.0   Brown coal  Outflow
# 18                 Change in stock     -2398580.0   Brown coal    Stock
# 19           Indigenous production     12442679.0    Hard coal   Inflow
# 20                         Imports     31964361.0    Hard coal   Inflow
# 21                         Exports      3860104.0    Hard coal  Outflow
# 22                 Change in stock       118625.0    Hard coal    Stock
# 23           Indigenous production     37279110.0    Hard coal   Inflow
# 24                         Imports     59037530.0    Hard coal   Inflow
# 25                         Exports      6171241.0    Hard coal  Outflow
# 26                 Change in stock     -3705978.0    Hard coal    Stock
# 27           Indigenous production    224909414.0   Brown coal   Inflow
# 28                         Imports      1574814.0   Brown coal   Inflow
# 29                         Exports      2719968.0   Brown coal  Outflow

# %%
# Map so "Gas" flows find "Natural gas" factors in ccf 
mapping = {
    'Gas': 'Natural gas', 
    'Crude oil': 'Crude oil', 
    'Hard coal': 'Hard coal', 
    'Brown coal': 'Brown coal', 
    'Refined oil': 'Refined oil',
    'Peat': 'Peat'
}
df_fossil_inflows_clean['CCF_Match'] = df_fossil_inflows_clean['Carrier'].map(mapping)

# Merge 'Carbon content factor' column to fossil data
df_carbon_fossil_inflow = df_fossil_inflows_clean.merge(ccf_clean, left_on='CCF_Match', right_on='Carrier', how='left', suffixes=('', '_ccf'))

df_carbon_fossil_inflow['Amount_tonnes'] = pd.to_numeric(df_carbon_fossil_inflow['Amount_tonnes'], errors='coerce')
df_carbon_fossil_inflow['Carbon content factor'] = pd.to_numeric(df_carbon_fossil_inflow['Carbon content factor'], errors='coerce')

# multiply ccf with amount tonnes to get tonnes of carbon
df_carbon_fossil_inflow['tonnes_Carbon'] = df_carbon_fossil_inflow['Amount_tonnes'] * df_carbon_fossil_inflow['Carbon content factor']


# if you want to save the result, uncomment the following line:
# df_carbon_fossil_inflow.to_csv('Calculated_Fossil_Carbon_Fixed.csv', index=False)
# or inspect the columns, check for missing values, etc.:
df_carbon_fossil_inflow.info()
df_carbon_fossil_inflow.head(30)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Flow                   64 non-null     str
#  1   Added info             64 non-null     str
#  2   Amount_tonnes          64 non-null     float64
#  3   Carrier                64 non-null     str
#  4   Type                   64 non-null     str
#  5   CCF_Match              64 non-null     str
#  6   Carrier_ccf            64 non-null     str
#  7   Carbon content factor  64 non-null     float64
#  8   tonnes_Carbon          64 non-null     float64
# dtypes: float64(3), str(6)
# memory usage: 4.6 KB
#                                                  Flow  \
# 0   Crude oil, NGL, refinery feedstocks, additives...
# 1   Crude oil, NGL, refinery feedstocks, additives...
# 2   Crude oil, NGL, refinery feedstocks, additives...
# 3   Crude oil, NGL, refinery feedstocks, additives...
# 4                                        Oil products
# 5                                        Oil products
# 6                                        Oil products
# 7                                        Oil products
# 8                                           Hard coal
# 9                                           Hard coal
# 10                                          Hard coal
# 11                                          Hard coal
# 12                                         Anthracite
# 13                                         Anthracite
# 14                                         Anthracite
# 15                                            Lignite
# 16                                            Lignite
# 17                                            Lignite
# 18                                            Lignite
# 19                                        Coking coal
# 20                                        Coking coal
# 21                                        Coking coal
# 22                                        Coking coal
# 23                              Other bituminous coal
# 24                              Other bituminous coal
# 25                              Other bituminous coal
# 26                              Other bituminous coal
# 27                                         Brown coal
# 28                                         Brown coal
# 29                                         Brown coal
#
#                         Added info  Amount_tonnes      Carrier     Type  \
# 0            Indigenous production     19057031.0    Crude oil   Inflow
# 1                          Imports    497079537.0    Crude oil   Inflow
# 2                          Exports     14406378.0    Crude oil  Outflow
# 3                  Change in stock      4042544.0    Crude oil    Stock
# 4                          Imports    288398077.0  Refined oil   Inflow
# 5                          Exports    299995871.0  Refined oil  Outflow
# 6                  Change in stock      2165148.0  Refined oil    Stock
# 7   International maritime bunkers     39641986.0  Refined oil  Outflow
# 8            Indigenous production     49721789.0    Hard coal   Inflow
# 9                          Imports     92422554.0    Hard coal   Inflow
# 10                         Exports     10291620.0    Hard coal  Outflow
# 11                 Change in stock     -3499952.0    Hard coal    Stock
# 12                         Imports      1420663.0    Hard coal   Inflow
# 13                         Exports       260275.0    Hard coal  Outflow
# 14                 Change in stock        87401.0    Hard coal    Stock
# 15           Indigenous production    224909414.0   Brown coal   Inflow
# 16                         Imports       805566.0   Brown coal   Inflow
# 17                         Exports      2716868.0   Brown coal  Outflow
# 18                 Change in stock     -2398580.0   Brown coal    Stock
# 19           Indigenous production     12442679.0    Hard coal   Inflow
# 20                         Imports     31964361.0    Hard coal   Inflow
# 21                         Exports      3860104.0    Hard coal  Outflow
# 22                 Change in stock       118625.0    Hard coal    Stock
# 23           Indigenous production     37279110.0    Hard coal   Inflow
# 24                         Imports     59037530.0    Hard coal   Inflow
# 25                         Exports      6171241.0    Hard coal  Outflow
# 26                 Change in stock     -3705978.0    Hard coal    Stock
# 27           Indigenous production    224909414.0   Brown coal   Inflow
# 28                         Imports      1574814.0   Brown coal   Inflow
# 29                         Exports      2719968.0   Brown coal  Outflow
#
#       CCF_Match  Carrier_ccf  Carbon content factor  tonnes_Carbon
# 0     Crude oil    Crude oil                  0.846   1.612225e+07
# 1     Crude oil    Crude oil                  0.846   4.205293e+08
# 2     Crude oil    Crude oil                  0.846   1.218780e+07
# 3     Crude oil    Crude oil                  0.846   3.419992e+06
# 4   Refined oil  Refined oil                  0.856   2.468688e+08
# 5   Refined oil  Refined oil                  0.856   2.567965e+08
# 6   Refined oil  Refined oil                  0.856   1.853367e+06
# 7   Refined oil  Refined oil                  0.856   3.393354e+07
# 8     Hard coal    Hard coal                  0.716   3.560080e+07
# 9     Hard coal    Hard coal                  0.716   6.617455e+07
# 10    Hard coal    Hard coal                  0.716   7.368800e+06
# 11    Hard coal    Hard coal                  0.716  -2.505966e+06
# 12    Hard coal    Hard coal                  0.716   1.017195e+06
# 13    Hard coal    Hard coal                  0.716   1.863569e+05
# 14    Hard coal    Hard coal                  0.716   6.257912e+04
# 15   Brown coal   Brown coal                  0.328   7.377029e+07
# 16   Brown coal   Brown coal                  0.328   2.642256e+05
# 17   Brown coal   Brown coal                  0.328   8.911327e+05
# 18   Brown coal   Brown coal                  0.328  -7.867342e+05
# 19    Hard coal    Hard coal                  0.716   8.908958e+06
# 20    Hard coal    Hard coal                  0.716   2.288648e+07
# 21    Hard coal    Hard coal                  0.716   2.763834e+06
# 22    Hard coal    Hard coal                  0.716   8.493550e+04
# 23    Hard coal    Hard coal                  0.716   2.669184e+07
# 24    Hard coal    Hard coal                  0.716   4.227087e+07
# 25    Hard coal    Hard coal                  0.716   4.418609e+06
# 26    Hard coal    Hard coal                  0.716  -2.653480e+06
# 27   Brown coal   Brown coal                  0.328   7.377029e+07
# 28   Brown coal   Brown coal                  0.328   5.165390e+05
# 29   Brown coal   Brown coal                  0.328   8.921495e+05

# %%
# this is the non_calc version because the primary and secondary inflows are still in the same dataframe and can be confused with eachother
df_carbon_fossil_inflow.to_csv('/Users/charlottewestenberg/Thesis/00data/processed/Fossil_Carbon_Inflow_non_calc.csv', index=False)

# %%
df_carbon_fossil_inflow['Flow'].unique()
# Out:
# <StringArray>
# ['Crude oil, NGL, refinery feedstocks, additives and oxygenates and other hydrocarbons',
#                                                                          'Oil products',
#                                                                             'Hard coal',
#                                                                            'Anthracite',
#                                                                               'Lignite',
#                                                                           'Coking coal',
#                                                                 'Other bituminous coal',
#                                                                            'Brown coal',
#                                                                   'Sub-bituminous coal',
#                                                                        'Coke oven coke',
#                                                                           'Patent fuel',
#                                                                 'Brown coal briquettes',
#                                                                              'Coal tar',
#                                                                                  'Peat',
#                                                                         'Peat products',
#                                                               'Oil shale and oil sands',
#                                                                           'Natural gas']
# Length: 17, dtype: str

# %%
# Xeperate the primary fossil inflows into a seperate dataflow. 
# This eurostat dataflow contains both primary and secondary fossil inflows, this means it is counting the carbon inflows double when summing the total

primary_fuels = [
    "Crude oil, NGL, refinery feedstocks, additives and oxygenates and other hydrocarbons",
    "Natural gas",
    "Hard coal",
    "Brown coal",
    "Oil shale and oil sands",
    "Peat"
]

df_primary_fossil = df_carbon_fossil_inflow[df_carbon_fossil_inflow["Flow"].isin(primary_fuels)]

# %%
def fossil_supply_calc(group):

    production = group.loc[group["Added info"] == "Indigenous production", "tonnes_Carbon"].sum()
    imports = group.loc[group["Added info"] == "Imports", "tonnes_Carbon"].sum()
    exports = group.loc[group["Added info"] == "Exports", "tonnes_Carbon"].sum()
    stock = group.loc[group["Added info"] == "Change in stock", "tonnes_Carbon"].sum()
    bunkers = group.loc[group["Added info"] == "International maritime bunkers", "tonnes_Carbon"].sum()

    return production + imports - exports - bunkers - stock


fossil_supply_by_fuel = df_primary_fossil.groupby("Flow").apply(fossil_supply_calc)
total_fossil_supply = fossil_supply_by_fuel.sum()

print(fossil_supply_by_fuel, 'the total fossil supply is:', total_fossil_supply)
# Out:
# Flow
# Brown coal                                                                              7.422506e+07
# Crude oil, NGL, refinery feedstocks, additives and oxygenates and other hydrocarbons    4.210437e+08
# Hard coal                                                                               9.691252e+07
# Natural gas                                                                             1.770591e+08
# Oil shale and oil sands                                                                 1.249171e+07
# Peat                                                                                    1.108773e+05
# dtype: float64 the total fossil supply is: 781842995.8202001

# %%
fossil_supply_df = fossil_supply_by_fuel.reset_index()
fossil_supply_df.columns = ["Flow", "Fossil_supply_tC"]

fossil_supply_df
#fossil_supply_df["Type"] = "Fossil inflow"
fossil_supply_df.to_csv('/Users/charlottewestenberg/Thesis/00data/processed/Aggregated_Fossil_Carbon_Inflow.csv', index=False)

# %%
df_final_fossil_inflow = df_primary_fossil.drop(columns=['Amount_tonnes', 'CCF_Match', 'Carrier_ccf', 'Carbon content factor'])
df_final_fossil_inflow.to_csv('/Users/charlottewestenberg/Thesis/00data/processed/Calculated_Primary_Fossil_Carbon_Inflow.csv', index=False)

# %% [markdown]
# ### GHG

# %%
#creating ghg outflows dataframe and cleaning it for use in calculations
# If refering to Excel, use: pd.read_excel('[name].xlsx', sheet_name='XXX')
df_ghg_outflows = pd.read_csv('/Users/charlottewestenberg/Thesis/00data/from_excel/_PC_ghg_emissions.csv')
df_ghg_outflows.columns
# Out:
# Index(['Flow', 'Added info', 'Unit in dataset', '#CO2 in dataset',
#        'Amount_tonnes_CO2', '#CH4 in dataset', 'Amount_tonnes_CH4',
#        '#CO in dataset', 'Amount_tonnes_CO', 'Sankey node flow name', 'Type',
#        'Source'],
#       dtype='str')

# %%
df_ghg_outflows_clean = df_ghg_outflows.drop(columns=['Unit in dataset', '#CO2 in dataset', '#CH4 in dataset', '#CO in dataset', 'Source'])
df_ghg_outflows_clean.info()
df_ghg_outflows_clean.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Flow                   11 non-null     str
#  1   Added info             27 non-null     str
#  2   Amount_tonnes_CO2      31 non-null     float64
#  3   Amount_tonnes_CH4      31 non-null     float64
#  4   Amount_tonnes_CO       31 non-null     float64
#  5   Sankey node flow name  31 non-null     str
#  6   Type                   31 non-null     str
# dtypes: float64(3), str(4)
# memory usage: 4.1 KB
#                                                Flow  \
# 0                          1.A.1. Energy industries
# 1                                               NaN
# 2                                               NaN
# 3  1.A.2. Manufacturing industries and construction
# 4                                               NaN
#
#                                           Added info  Amount_tonnes_CO2  \
# 0    1.A.1.a. Public electricity and heat production       5.679841e+08
# 1                        1.A.1.b. Petroleum refining       9.290136e+07
# 2  1.A.1.c. Manufacture of solid fuels and other ...       2.765303e+07
# 3                            1.A.2.a. Iron and steel       6.759795e+07
# 4                        1.A.2.b. Non-ferrous metals       7.721146e+06
#
#    Amount_tonnes_CH4  Amount_tonnes_CO Sankey node flow name     Type
# 0      119356.697800      283681.48470     Energy production  Outflow
# 1        2359.067881       17549.60913                Energy  Outflow
# 2        6357.444519       82132.55458                Energy  Outflow
# 3        4597.164908      613217.15560         Manufacturing  Outflow
# 4         391.923416       12262.71470         Manufacturing  Outflow

# %%
# dropping ghost rows from the old excel file (all the 31 nan rows)

df_ghg_outflows_clean = df_ghg_outflows_clean.dropna(subset=['Sankey node flow name'])

df_ghg_outflows_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Flow                   11 non-null     str
#  1   Added info             27 non-null     str
#  2   Amount_tonnes_CO2      31 non-null     float64
#  3   Amount_tonnes_CH4      31 non-null     float64
#  4   Amount_tonnes_CO       31 non-null     float64
#  5   Sankey node flow name  31 non-null     str
#  6   Type                   31 non-null     str
# dtypes: float64(3), str(4)
# memory usage: 1.8 KB

# %%
ccf_library = df_ccf.dropna(subset=['Carbon content factor'])
ccf_library = dict(zip(ccf_library['Carrier'], ccf_library['Carbon content factor']))

# Print it to see your "Library"
print("Your Automated CCF Library:")
for carrier, value in ccf_library.items():
    print(f" - {carrier}: {value} kg C/kg")
# Out:
# Your Automated CCF Library:
#  - Hard coal: 0.716 kg C/kg
#  - Brown coal: 0.328 kg C/kg
#  - Peat: 0.282 kg C/kg
#  - Natural gas: 15.3 kg C/kg
#  - Crude oil: 0.846 kg C/kg
#  - Refined oil: 0.856 kg C/kg
#  - Petroleum coke: 0.863 kg C/kg
#  - Coke (from coal): 0.823 kg C/kg
#  - Petrochemical feedstock: 0.869 kg C/kg
#  - Primary biomass: 0.5 kg C/kg
#  - Wood pellets / Timber of Biomass forestry: 0.476 kg C/kg
#  - Crops & livestock: 0.48 kg C/kg
#  - Non-food biomass: 0.62 kg C/kg
#  - Limestone: 0.12 kg C/kg
#  - Virgin plastics: 0.741 kg C/kg
#  - Transport fuels: 0.856 kg C/kg
#  - CO2 : 0.27 kg C/kg
#  - CH4 : 0.75 kg C/kg
#  - CO: 0.428 kg C/kg
#  - Plastic waste: 0.741 kg C/kg
#  - Plastics in buildings: 0.741 kg C/kg
#  - Wood in construction: 0.476 kg C/kg
#  - Bitumen in roads: 0.884 kg C/kg

# %%
CCF_FACTORS = {
    'Amount_tonnes_CO2': 0.27,
    'Amount_tonnes_CH4': 0.75,
    'Amount_tonnes_CO': 0.4286
}
		

# 3. Clean and Multiply in one loop
# This ensures columns are numeric and then creates new 'Carbon' columns
for gas, factor in CCF_FACTORS.items():
    if gas in df_ghg_outflows_clean.columns:
        df_ghg_outflows_clean[gas] = pd.to_numeric(df_ghg_outflows_clean[gas], errors='coerce').fillna(0)
        new_col_name = f'Carbon_from_{gas}'
        df_ghg_outflows_clean[new_col_name] = df_ghg_outflows_clean[gas] * factor

# 4. Total Carbon from all GHGs
# This sums up the new columns to give you the total carbon outflow
carbon_cols = [f'Carbon_from_{gas}' for gas in CCF_FACTORS.keys() if gas in df_ghg_outflows_clean.columns]
df_ghg_outflows_clean['Total_Carbon_GHG'] = df_ghg_outflows_clean[carbon_cols].sum(axis=1)

df_ghg_outflows_clean.head()

# Save result
#df_ghg_outflows_clean.to_csv('Calculated_GHG_Carbon.csv', index=False)
# Out:
#                                                Flow  \
# 0                          1.A.1. Energy industries
# 1                                               NaN
# 2                                               NaN
# 3  1.A.2. Manufacturing industries and construction
# 4                                               NaN
#
#                                           Added info  Amount_tonnes_CO2  \
# 0    1.A.1.a. Public electricity and heat production       5.679841e+08
# 1                        1.A.1.b. Petroleum refining       9.290136e+07
# 2  1.A.1.c. Manufacture of solid fuels and other ...       2.765303e+07
# 3                            1.A.2.a. Iron and steel       6.759795e+07
# 4                        1.A.2.b. Non-ferrous metals       7.721146e+06
#
#    Amount_tonnes_CH4  Amount_tonnes_CO Sankey node flow name     Type  \
# 0      119356.697800      283681.48470     Energy production  Outflow
# 1        2359.067881       17549.60913                Energy  Outflow
# 2        6357.444519       82132.55458                Energy  Outflow
# 3        4597.164908      613217.15560         Manufacturing  Outflow
# 4         391.923416       12262.71470         Manufacturing  Outflow
#
#    Carbon_from_Amount_tonnes_CO2  Carbon_from_Amount_tonnes_CH4  \
# 0                   1.533557e+08                   89517.523350
# 1                   2.508337e+07                    1769.300911
# 2                   7.466318e+06                    4768.083389
# 3                   1.825145e+07                    3447.873681
# 4                   2.084709e+06                     293.942562
#
#    Carbon_from_Amount_tonnes_CO  Total_Carbon_GHG
# 0                 121585.884342      1.535668e+08
# 1                   7521.762473      2.509266e+07
# 2                  35202.012893      7.506288e+06
# 3                 262824.872890      1.851772e+07
# 4                   5255.799520      2.090259e+06

# %%
df_ghg_outflows_clean.drop(columns=['Amount_tonnes_CO2', 'Amount_tonnes_CH4', 'Amount_tonnes_CO'], inplace=True)
df_ghg_outflows_clean = df_ghg_outflows_clean.rename(columns={
    'Carbon_from_Amount_tonnes_CO2': 'Carbon_from_CO2',
    'Carbon_from_Amount_tonnes_CH4': 'Carbon_from_CH4',
    'Carbon_from_Amount_tonnes_CO': 'Carbon_from_CO'
    })

# %%
df_ghg_outflows_clean.to_csv('/Users/charlottewestenberg/Thesis/00data/processed/Calculated_GHG_Carbon_Outflow.csv', index=False)

# %% [markdown]
# ## Fossil inflows 19/3
# The data was suddenly changed/updated by the EU. Sent them an email about this. For now, quickly checking how much has changed. Sankey diagram is as of 19/3 still using the old data from 11/3 bc that dataset was manually built.

# %%
df_fossil_inflows19 = pd.read_csv('/Users/charlottewestenberg/Thesis/00data/from_excel/Fossil inflows 19-3 copy.csv')
df_fossil_inflows_clean19 = df_fossil_inflows19.drop(columns=['Amount in dataset', 'Unit in dataset', 'Source'])

# %%
df_fossil_inflows_clean19.head(15)
# Out:
#                                                  Flow  \
# 0   Crude oil, NGL, refinery feedstocks, additives...
# 1   Crude oil, NGL, refinery feedstocks, additives...
# 2   Crude oil, NGL, refinery feedstocks, additives...
# 3   Crude oil, NGL, refinery feedstocks, additives...
# 4                                        Oil products
# 5                                        Oil products
# 6                                        Oil products
# 7                                        Oil products
# 8                                           Hard coal
# 9                                           Hard coal
# 10                                          Hard coal
# 11                                          Hard coal
# 12                                         Anthracite
# 13                                         Anthracite
# 14                                         Anthracite
#
#                         Added info  Amount_tonnes      Carrier     Type
# 0            Indigenous production     19057031.0    Crude oil   Inflow
# 1                          Imports    497079537.0    Crude oil   Inflow
# 2                          Exports     14406378.0    Crude oil  Outflow
# 3                  Change in stock      4042544.0    Crude oil    Stock
# 4                          Imports    288398077.0  Refined oil   Inflow
# 5                          Exports    299995871.0  Refined oil  Outflow
# 6                  Change in stock      2165148.0  Refined oil    Stock
# 7   International maritime bunkers     39641986.0  Refined oil  Outflow
# 8            Indigenous production     49721789.0    Hard coal   Inflow
# 9                          Imports     92384173.0    Hard coal   Inflow
# 10                         Exports     10239620.0    Hard coal  Outflow
# 11                 Change in stock     -3508698.0    Hard coal    Stock
# 12                         Imports      1448410.0    Hard coal   Inflow
# 13                         Exports       260275.0    Hard coal  Outflow
# 14                 Change in stock        68216.0    Hard coal    Stock

# %%
# Map so "Gas" flows find "Natural gas" factors in ccf 
mapping = {
    'Gas': 'Natural gas', 
    'Crude oil': 'Crude oil', 
    'Hard coal': 'Hard coal', 
    'Brown coal': 'Brown coal', 
    'Refined oil': 'Refined oil',
    'Peat': 'Peat'
}
df_fossil_inflows_clean19['CCF_Match'] = df_fossil_inflows_clean19['Carrier'].map(mapping)

# Merge 'Carbon content factor' column to fossil data
df_carbon_fossil_inflow19 = df_fossil_inflows_clean19.merge(ccf_clean, left_on='CCF_Match', right_on='Carrier', how='left', suffixes=('', '_ccf'))

df_carbon_fossil_inflow19['Amount_tonnes'] = pd.to_numeric(df_carbon_fossil_inflow19['Amount_tonnes'], errors='coerce')
df_carbon_fossil_inflow19['Carbon content factor'] = pd.to_numeric(df_carbon_fossil_inflow19['Carbon content factor'], errors='coerce')

# multiply ccf with amount tonnes to get tonnes of carbon
df_carbon_fossil_inflow19['tonnes_Carbon'] = df_carbon_fossil_inflow19['Amount_tonnes'] * df_carbon_fossil_inflow19['Carbon content factor']


# if you want to save the result, uncomment the following line:
# df_carbon_fossil_inflow19.to_csv('Calculated_Fossil_Carbon_Fixed.csv', index=False)
# or inspect the columns, check for missing values, etc.:

# %%
df_carbon_fossil_inflow19.head(30)
# Out:
#                                                  Flow  \
# 0   Crude oil, NGL, refinery feedstocks, additives...
# 1   Crude oil, NGL, refinery feedstocks, additives...
# 2   Crude oil, NGL, refinery feedstocks, additives...
# 3   Crude oil, NGL, refinery feedstocks, additives...
# 4                                        Oil products
# 5                                        Oil products
# 6                                        Oil products
# 7                                        Oil products
# 8                                           Hard coal
# 9                                           Hard coal
# 10                                          Hard coal
# 11                                          Hard coal
# 12                                         Anthracite
# 13                                         Anthracite
# 14                                         Anthracite
# 15                                            Lignite
# 16                                            Lignite
# 17                                            Lignite
# 18                                            Lignite
# 19                                        Coking coal
# 20                                        Coking coal
# 21                                        Coking coal
# 22                                        Coking coal
# 23                              Other bituminous coal
# 24                              Other bituminous coal
# 25                              Other bituminous coal
# 26                              Other bituminous coal
# 27                                         Brown coal
# 28                                         Brown coal
# 29                                         Brown coal
#
#                         Added info  Amount_tonnes      Carrier     Type  \
# 0            Indigenous production     19057031.0    Crude oil   Inflow
# 1                          Imports    497079537.0    Crude oil   Inflow
# 2                          Exports     14406378.0    Crude oil  Outflow
# 3                  Change in stock      4042544.0    Crude oil    Stock
# 4                          Imports    288398077.0  Refined oil   Inflow
# 5                          Exports    299995871.0  Refined oil  Outflow
# 6                  Change in stock      2165148.0  Refined oil    Stock
# 7   International maritime bunkers     39641986.0  Refined oil  Outflow
# 8            Indigenous production     49721789.0    Hard coal   Inflow
# 9                          Imports     92384173.0    Hard coal   Inflow
# 10                         Exports     10239620.0    Hard coal  Outflow
# 11                 Change in stock     -3508698.0    Hard coal    Stock
# 12                         Imports      1448410.0    Hard coal   Inflow
# 13                         Exports       260275.0    Hard coal  Outflow
# 14                 Change in stock        68216.0    Hard coal    Stock
# 15           Indigenous production    224909414.0   Brown coal   Inflow
# 16                         Imports       805566.0   Brown coal   Inflow
# 17                         Exports      2716868.0   Brown coal  Outflow
# 18                 Change in stock     -2383009.0   Brown coal    Stock
# 19           Indigenous production     12442679.0    Hard coal   Inflow
# 20                         Imports     31963153.0    Hard coal   Inflow
# 21                         Exports      3860104.0    Hard coal  Outflow
# 22                 Change in stock       118625.0    Hard coal    Stock
# 23           Indigenous production     37279110.0    Hard coal   Inflow
# 24                         Imports     58972610.0    Hard coal   Inflow
# 25                         Exports      6119241.0    Hard coal  Outflow
# 26                 Change in stock     -3695539.0    Hard coal    Stock
# 27           Indigenous production    224909414.0   Brown coal   Inflow
# 28                         Imports      1574814.0   Brown coal   Inflow
# 29                         Exports      2719968.0   Brown coal  Outflow
#
#       CCF_Match  Carrier_ccf  Carbon content factor  tonnes_Carbon
# 0     Crude oil    Crude oil                  0.846   1.612225e+07
# 1     Crude oil    Crude oil                  0.846   4.205293e+08
# 2     Crude oil    Crude oil                  0.846   1.218780e+07
# 3     Crude oil    Crude oil                  0.846   3.419992e+06
# 4   Refined oil  Refined oil                  0.856   2.468688e+08
# 5   Refined oil  Refined oil                  0.856   2.567965e+08
# 6   Refined oil  Refined oil                  0.856   1.853367e+06
# 7   Refined oil  Refined oil                  0.856   3.393354e+07
# 8     Hard coal    Hard coal                  0.716   3.560080e+07
# 9     Hard coal    Hard coal                  0.716   6.614707e+07
# 10    Hard coal    Hard coal                  0.716   7.331568e+06
# 11    Hard coal    Hard coal                  0.716  -2.512228e+06
# 12    Hard coal    Hard coal                  0.716   1.037062e+06
# 13    Hard coal    Hard coal                  0.716   1.863569e+05
# 14    Hard coal    Hard coal                  0.716   4.884266e+04
# 15   Brown coal   Brown coal                  0.328   7.377029e+07
# 16   Brown coal   Brown coal                  0.328   2.642256e+05
# 17   Brown coal   Brown coal                  0.328   8.911327e+05
# 18   Brown coal   Brown coal                  0.328  -7.816270e+05
# 19    Hard coal    Hard coal                  0.716   8.908958e+06
# 20    Hard coal    Hard coal                  0.716   2.288562e+07
# 21    Hard coal    Hard coal                  0.716   2.763834e+06
# 22    Hard coal    Hard coal                  0.716   8.493550e+04
# 23    Hard coal    Hard coal                  0.716   2.669184e+07
# 24    Hard coal    Hard coal                  0.716   4.222439e+07
# 25    Hard coal    Hard coal                  0.716   4.381377e+06
# 26    Hard coal    Hard coal                  0.716  -2.646006e+06
# 27   Brown coal   Brown coal                  0.328   7.377029e+07
# 28   Brown coal   Brown coal                  0.328   5.165390e+05
# 29   Brown coal   Brown coal                  0.328   8.921495e+05

# %%
primary_fuels
# Out:
# ['Crude oil, NGL, refinery feedstocks, additives and oxygenates and other hydrocarbons',
#  'Natural gas',
#  'Hard coal',
#  'Brown coal',
#  'Oil shale and oil sands',
#  'Peat']

# %%
def fossil_supply_calc(group):

    production = group.loc[group["Added info"] == "Indigenous production", "tonnes_Carbon"].sum()
    imports = group.loc[group["Added info"] == "Imports", "tonnes_Carbon"].sum()
    exports = group.loc[group["Added info"] == "Exports", "tonnes_Carbon"].sum()
    stock = group.loc[group["Added info"] == "Change in stock", "tonnes_Carbon"].sum()
    bunkers = group.loc[group["Added info"] == "International maritime bunkers", "tonnes_Carbon"].sum()

    return production + imports - exports - bunkers - stock


fossil_supply_by_fuel = df_primary_fossil.groupby("Flow").apply(fossil_supply_calc)
total_fossil_supply = fossil_supply_by_fuel.sum()

print(fossil_supply_by_fuel, 'the total fossil supply is:', total_fossil_supply)
# Out:
# Flow
# Brown coal                                                                              7.422506e+07
# Crude oil, NGL, refinery feedstocks, additives and oxygenates and other hydrocarbons    4.210437e+08
# Hard coal                                                                               9.691252e+07
# Natural gas                                                                             1.770591e+08
# Oil shale and oil sands                                                                 1.249171e+07
# Peat                                                                                    1.108773e+05
# dtype: float64 the total fossil supply is: 781842995.8202001

# %%
df_primary_fossil19 = df_carbon_fossil_inflow19[df_carbon_fossil_inflow19["Flow"].isin(primary_fuels)]

fossil_supply_by_fuel19 = df_primary_fossil19.groupby("Flow").apply(fossil_supply_calc)
total_fossil_supply19 = fossil_supply_by_fuel19.sum()

print(fossil_supply_by_fuel19, 'the total fossil supply is:', total_fossil_supply19)
# Out:
# Flow
# Brown coal                                                                              7.421995e+07
# Crude oil, NGL, refinery feedstocks, additives and oxygenates and other hydrocarbons    4.210437e+08
# Hard coal                                                                               9.692853e+07
# Natural gas                                                                             1.769200e+08
# Oil shale and oil sands                                                                 1.249171e+07
# Peat                                                                                    9.473983e+05
# dtype: float64 the total fossil supply is: 782551366.3010001

# %%
total_fossil_supply19-total_fossil_supply
# Out:
# np.float64(708370.4808000326)
