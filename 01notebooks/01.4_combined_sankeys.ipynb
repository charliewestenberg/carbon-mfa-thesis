# %%
# import necessary libraries
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# # Combined Sankey

# %%
# Load the CSV
df_combined = pd.read_csv("/Users/charlottewestenberg/Thesis/00data/from_excel/total sankey - policy cov.csv")

# create unique node list
all_nodes = pd.concat([df_combined["Source"], df_combined["Target"]]).unique()
node_dict = {node: i for i, node in enumerate(all_nodes)}

# map to numeric IDs
df_combined["source_id"] = df_combined["Source"].map(node_dict)
df_combined["target_id"] = df_combined["Target"].map(node_dict)

carrier_colors = {
    "Limestone (Manufacturing)": "rgba(120, 140, 190, 0.85)",  # clearer blue (industrial)
    "Limestone (Aggregates)":    "rgba(200, 185, 140, 0.80)",  # sandy beige (construction feel)
    "Mixed Mineral":             "rgba(150, 140, 130, 0.75)",  # neutral warm grey (mix)
    "Oil":                "rgba(40, 40, 40, 0.85)",        # near-black
    "Gas":                "rgba(255, 165, 0, 0.75)",        # amber orange
    "Coal":               "rgba(90, 60, 40, 0.85)",         # dark brown
    "Refinery Products":  "rgba(160, 110, 60, 0.75)",       # mid warm brown
    "Fossil materials":   "rgba(200, 160, 100, 0.5)",      # light tan
    "Carbon Emissions":   "rgba(220, 50, 50, 0.75)",  # bright red for emissions
    "Crops":              "rgba(120, 190, 80, 0.75)",     # brighter, more yellow-green
    "Wood":               "rgba(40, 100, 40, 0.9)",      # deeper, darker forest green
    "Animal Products":    "rgba(220, 180, 90, 0.8)",     # shifted toward warm ochre (less green)
    "Products from biomass": "rgba(50, 150, 170, 0.8)",  # clearer teal (more blue)
    "Mixed Biogenic":     "rgba(120, 140, 120, 0.7)",    # muted grey-green (neutral mix)
    "Carbon Emissions (Biogenic)": "rgba(230, 110, 40, 0.8)",  # stronger orange (distinct from fossil red)
    "Mixed Material":            "rgba(170, 170, 170, 0.7)",   # neutral grey (for mixed/uncategorized)
}

df_combined["color"] = df_combined["Carrier"].map(carrier_colors).fillna("rgba(200,200,200,0.4)")

#calculate outflows per source and target nodes
source_totals = df_combined.groupby("Source")["Value_tC"].sum()
node_inflow = df_combined.groupby("Target")["Value_tC"].sum()

labels_with_values = []
for node in all_nodes:
    inflow = node_inflow.get(node, 0)
    outflow = source_totals.get(node, 0)
    # choose what to display
    value = inflow if inflow > 0 else outflow
    if value > 0:
        labels_with_values.append(f"{node}<br>{value/1e6:.1f} MtC")
    else:
        labels_with_values.append(node)

fig = go.Figure(data=[go.Sankey(
    
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=labels_with_values,
        color="lightgrey"
    ),

    link=dict(
        source=df_combined["source_id"],
        target=df_combined["target_id"],
        value=df_combined["Value_tC"],
        color=df_combined["color"]
    )
)])

for carrier, color in carrier_colors.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(size=10, color=color),
        legendgroup=carrier,
        showlegend=True,
        name=carrier
    ))

fig.update_layout(
    title_text="EU Carbon Flows (2023)",
    font_size=14,
    width=1600,
    height=1000,
    showlegend=True,
    legend=dict(
        title="Energy carrier",
        orientation="h",
        y=-0.1
    ),
    xaxis=dict(visible=False),
    yaxis=dict(visible=False),
    plot_bgcolor="white",
    paper_bgcolor="white"
)

fig.show()

# %% [markdown]
# # Combined Sankey - Policy Coverage

# %%
# Load the CSV
df_combined = pd.read_csv("/Users/charlottewestenberg/Thesis/00data/from_excel/total sankey - policy cov.csv")

# create unique node list
all_nodes = pd.concat([df_combined["Source"], df_combined["Target"]]).unique()
node_dict = {node: i for i, node in enumerate(all_nodes)}

# map to numeric IDs
df_combined["source_id"] = df_combined["Source"].map(node_dict)
df_combined["target_id"] = df_combined["Target"].map(node_dict)

policy_colors = {
    "yes":   "rgba(220, 50, 50, 0.75)",  # bright red for emissions
    "no":            "rgba(170, 170, 170, 0.7)",   # neutral grey (for mixed/uncategorized)
}

df_combined["color"] = df_combined["policy_cov"].map(policy_colors).fillna("rgba(200,200,200,0.4)")

#calculate outflows per source and target nodes
source_totals = df_combined.groupby("Source")["Value_tC"].sum()
node_inflow = df_combined.groupby("Target")["Value_tC"].sum()

labels_with_values = []
for node in all_nodes:
    inflow = node_inflow.get(node, 0)
    outflow = source_totals.get(node, 0)
    # choose what to display
    value = inflow if inflow > 0 else outflow
    if value > 0:
        labels_with_values.append(f"{node}<br>{value/1e6:.1f} MtC")
    else:
        labels_with_values.append(node)

fig = go.Figure(data=[go.Sankey(
    
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=labels_with_values,
        color="lightgrey"
    ),

    link=dict(
        source=df_combined["source_id"],
        target=df_combined["target_id"],
        value=df_combined["Value_tC"],
        color=df_combined["color"]
    )
)])

for policy, color in policy_colors.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(size=10, color=color),
        legendgroup=policy,
        showlegend=True,
        name=policy
    ))

fig.update_layout(
    title_text="EU Carbon Flows (2023)",
    font_size=14,
    width=1600,
    height=1000,
    showlegend=True,
    legend=dict(
        title="Policy coverage",
        orientation="h",
        y=-0.1
    ),
    xaxis=dict(visible=False),
    yaxis=dict(visible=False),
    plot_bgcolor="white",
    paper_bgcolor="white"
)

fig.show()

# %%
# Load the CSV
df_combined = pd.read_csv("/Users/charlottewestenberg/Thesis/00data/from_excel/total sankey - policy cov.csv")

# create unique node list
all_nodes = pd.concat([df_combined["Source"], df_combined["Target"]]).unique()
node_dict = {node: i for i, node in enumerate(all_nodes)}

# map to numeric IDs
df_combined["source_id"] = df_combined["Source"].map(node_dict)
df_combined["target_id"] = df_combined["Target"].map(node_dict)

policy_colors = {
    "yes":   "rgba(220, 50, 50, 0.75)",  # bright red for emissions
    "no":            "rgba(170, 170, 170, 0.7)",   # neutral grey (for mixed/uncategorized)
}

df_combined["color"] = df_combined["policy_cov"].map(policy_colors).fillna("rgba(200,200,200,0.4)")

#calculate outflows per source and target nodes
source_totals = df_combined.groupby("Source")["Value_tC"].sum()
node_inflow = df_combined.groupby("Target")["Value_tC"].sum()

#group policies per node instead of flow
from collections import defaultdict
node_policies = defaultdict(set)

for _, row in df_combined.iterrows():
    if pd.notna(row["policy_name"]):
        policies = str(row["policy_name"]).split(",")
        policies = [p.strip() for p in policies if p.strip()]
        for policy in policies:
            node_policies[row["Target"]].add(policy)

excluded_node = "Carbon Emissions"

labels_with_values = []
for node in all_nodes:
    policies = node_policies.get(node, set())
    
    if node == excluded_node:
        labels_with_values.append(f"<b>{node}</b>")
        continue

    if policies:
        policy_text = "<br>".join(sorted(policies))
        labels_with_values.append(f"<b>{node}</b><br>{policy_text}")
    else:
        labels_with_values.append(f"<b>{node}</b>")

fig = go.Figure(data=[go.Sankey(
    
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=labels_with_values,
        color="lightgrey"
    ),

    link=dict(
        source=df_combined["source_id"],
        target=df_combined["target_id"],
        value=df_combined["Value_tC"],
        color=df_combined["color"]
    )
)])

for policy, color in policy_colors.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(size=10, color=color),
        legendgroup=policy,
        showlegend=True,
        name=policy
    ))

fig.update_layout(
    title_text="EU Carbon Flows (2023)",
    font_size=14,
    width=1500,
    height=1400,
    showlegend=True,
    legend=dict(
        title="Policy coverage",
        orientation="h",
        y=-0.1
    ),
    xaxis=dict(visible=False),
    yaxis=dict(visible=False),
    plot_bgcolor="white",
    paper_bgcolor="white"
)

fig.show()

# %%
# Load the CSV
df_combined = pd.read_csv("/Users/charlottewestenberg/Thesis/00data/from_excel/total sankey - policy cov.csv")

# create unique node list
all_nodes = pd.concat([df_combined["Source"], df_combined["Target"]]).unique()
node_dict = {node: i for i, node in enumerate(all_nodes)}

# map to numeric IDs
df_combined["source_id"] = df_combined["Source"].map(node_dict)
df_combined["target_id"] = df_combined["Target"].map(node_dict)

policy_type = {
    "cap":                      "rgba(60, 141, 113, 0.75)",
    "cap & tax":                "rgba(255, 99, 71, 0.75)",
    "cap & regulation & tax":   "rgba(220, 50, 50, 0.75)",
    "regulation":               "rgba(136, 194, 255, 0.75)",
    "cap & regulation":         "rgba(235, 170, 255, 0.75)",  
    "regulation & tax":         "rgba(255, 165, 0, 0.75)",
    "subsidy":                  "rgba(60, 194, 113, 0.75)",
    "regulation & subsidy":     "rgba(60, 170, 113, 0.75)",   
    "cap & regulation & subsidy": "rgba(60, 141, 113, 0.75)",
    "no":                       "rgba(170, 170, 170, 0.7)",
}

df_combined["color"] = df_combined["policy_type"].map(policy_type).fillna("rgba(170, 170, 170, 0.7)")

#calculate outflows per source and target nodes
source_totals = df_combined.groupby("Source")["Value_tC"].sum()
node_inflow = df_combined.groupby("Target")["Value_tC"].sum()

labels_with_values = []
for node in all_nodes:
    inflow = node_inflow.get(node, 0)
    outflow = source_totals.get(node, 0)
    # choose what to display
    value = inflow if inflow > 0 else outflow
    if value > 0:
        labels_with_values.append(f"{node}<br>{value/1e6:.1f} MtC")
    else:
        labels_with_values.append(node)

fig = go.Figure(data=[go.Sankey(
    
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=labels_with_values,
        color="lightgrey"
    ),

    link=dict(
        source=df_combined["source_id"],
        target=df_combined["target_id"],
        value=df_combined["Value_tC"],
        color=df_combined["color"]
    )
)])

for policy, color in policy_type.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(size=10, color=color),
        legendgroup=policy,
        showlegend=True,
        name=policy
    ))

fig.update_layout(
    title_text="EU Carbon Flows (2023)",
    font_size=14,
    width=1600,
    height=1000,
    showlegend=True,
    legend=dict(
        title="Policy coverage",
        orientation="h",
        y=-0.1
    ),
    xaxis=dict(visible=False),
    yaxis=dict(visible=False),
    plot_bgcolor="white",
    paper_bgcolor="white"
)

fig.show()
