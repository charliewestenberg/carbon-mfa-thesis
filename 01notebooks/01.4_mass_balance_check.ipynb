# %%
#import necessary libraries

import pandas as pd

# %%
df_fossil_inflows = pd.read_csv('/Users/charlottewestenberg/Thesis/00data/processed/Aggregated_Fossil_Carbon_Inflow.csv')
df_ghg_outflows = pd.read_csv('/Users/charlottewestenberg/Thesis/00data/processed/Calculated_GHG_Carbon_Outflow.csv')

# %%
total_outflow = df_ghg_outflows['Total_Carbon_GHG'].sum()
print(f"Total Carbon Outflow: {total_outflow} tonnes")
# Out:
# Total Carbon Outflow: 839616518.3185241 tonnes

# %%
total_fossil_inflow = df_fossil_inflows['Fossil_supply_tC'].sum()
print(f"Total Fossil Carbon Inflow: {total_fossil_inflow} tonnes")
# Out:
# Total Fossil Carbon Inflow: 869816453.3802 tonnes

# %%
print(f"Difference between inflow and outflow: {total_fossil_inflow - total_outflow} tonnes")
# Out:
# Difference between inflow and outflow: 30199935.061675906 tonnes

# %%
total_outflow/total_fossil_inflow
# Out:
# np.float64(0.9652801059990119)

# %%
# Out:
# 0.9652801059990119
