# %%
df_fossil_inflows_clean.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_fossil_inflows_clean.head()
#
# NameError: name 'df_fossil_inflows_clean' is not defined
